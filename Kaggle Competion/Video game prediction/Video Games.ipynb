# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
from matplotlib import style
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#       id  index                             Name Platform  Year_of_Release  \
# 0  10717   5596                        Darkwatch      PS2           2005.0
# 1  13346  12819  Ken to Mahou to Gakuen Mono. 3D      3DS           2011.0
# 2   1063   6098                          FIFA 15       PC           2014.0
# 3  12660   4932                  The Darkness II     X360           2012.0
# 4  11264  14483           Suggoi! Arcana Heart 2      PS2           2009.0
#
#           Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0       Shooter               Ubisoft      0.16      0.12      0.00
# 1  Role-Playing               Acquire      0.00      0.00      0.06
# 2        Sports       Electronic Arts      0.00      0.27      0.00
# 3       Shooter  Take-Two Interactive      0.24      0.11      0.00
# 4      Fighting        AQ Interactive      0.00      0.00      0.03
#
#    Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# ...

# %%
train.shape
# Out:
# (13375, 18)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13375 entries, 0 to 13374
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               13375 non-null  int64
#  1   index            13375 non-null  int64
#  2   Name             13373 non-null  object
#  3   Platform         13375 non-null  object
#  4   Year_of_Release  13150 non-null  float64
#  5   Genre            13373 non-null  object
#  6   Publisher        13328 non-null  object
#  7   NA_Sales         13375 non-null  float64
#  8   EU_Sales         13375 non-null  float64
#  9   JP_Sales         13375 non-null  float64
#  10  Other_Sales      13375 non-null  float64
#  11  Global_Sales     13375 non-null  float64
#  12  Critic_Score     6505 non-null   float64
#  13  Critic_Count     6505 non-null   float64
#  14  User_Score       8007 non-null   float64
#  15  User_Count       6039 non-null   float64
# ...

# %%
train.describe(include='all')
# Out:
#                   id         index                         Name Platform  \
# count   13375.000000  13375.000000                        13373    13375
# unique           NaN           NaN                         9759       30
# top              NaN           NaN  Need for Speed: Most Wanted      PS2
# freq             NaN           NaN                           11     1755
# mean     8373.976822   8361.879028                          NaN      NaN
# std      4835.675870   4817.625895                          NaN      NaN
# min         0.000000      1.000000                          NaN      NaN
# 25%      4200.500000   4208.500000                          NaN      NaN
# 50%      8354.000000   8358.000000                          NaN      NaN
# 75%     12574.500000  12518.500000                          NaN      NaN
# max     16718.000000  16718.000000                          NaN      NaN
#
#         Year_of_Release   Genre        Publisher      NA_Sales      EU_Sales  \
# ...

# %%
train.isnull().sum()
# Out:
# id                    0
# index                 0
# Name                  2
# Platform              0
# Year_of_Release     225
# Genre                 2
# Publisher            47
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       6870
# Critic_Count       6870
# User_Score         5368
# User_Count         7336
# Developer          5308
# Rating             5431
# dtype: int64

# %%
del train['Rating']
del train['Developer']
del train['User_Count']
del train['User_Score']
del train['Critic_Score']
del train['Critic_Count']
del train['Publisher']
del train['Year_of_Release']
del train['index']
del train['Name']
del train['Genre']
del train['Platform']

# %%
train.head()
# Out:
#       id  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  10717      0.16      0.12      0.00         0.04          0.32
# 1  13346      0.00      0.00      0.06         0.00          0.06
# 2   1063      0.00      0.27      0.00         0.02          0.28
# 3  12660      0.24      0.11      0.00         0.03          0.39
# 4  11264      0.00      0.00      0.03         0.00          0.03

# %%
X = train[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
y = train[['Global_Sales']]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
reg = model.fit(X_train, y_train)
reg.score(X_train, y_train)
# Out:
# 0.9999864942181869

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 0.0028672987342835557

# %% [markdown]
# ## Working on Testing dataset

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    id                     Name Platform  Year_of_Release     Genre  \
# 0  11        Caesars Palace II       PS           1998.0      Misc
# 1  12                  WWE '12      Wii           2011.0  Fighting
# 2  17       Dynasty Warriors 2      PS2           2000.0    Action
# 3  23  Crysis: Maximum Edition       PC           2009.0   Shooter
# 4  27            Pursuit Force      PSP           2005.0    Racing
#
#                      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                    Interplay      0.14      0.09      0.00         0.02
# 1                          THQ      0.23      0.08      0.00         0.03
# 2                          THQ      0.24      0.19      0.34         0.06
# 3              Electronic Arts      0.00      0.07      0.00         0.02
# 4  Sony Computer Entertainment      0.14      0.01      0.00         0.01
#
#    Critic_Score  Critic_Count  User_Score  User_Count        Developer Rating
# ...

# %%
test.shape
# Out:
# (3344, 16)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3344 entries, 0 to 3343
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3344 non-null   int64
#  1   Name             3344 non-null   object
#  2   Platform         3344 non-null   object
#  3   Year_of_Release  3300 non-null   float64
#  4   Genre            3344 non-null   object
#  5   Publisher        3337 non-null   object
#  6   NA_Sales         3344 non-null   float64
#  7   EU_Sales         3344 non-null   float64
#  8   JP_Sales         3344 non-null   float64
#  9   Other_Sales      3344 non-null   float64
#  10  Critic_Score     1632 non-null   float64
#  11  Critic_Count     1632 non-null   float64
#  12  User_Score       2008 non-null   float64
#  13  User_Count       1551 non-null   float64
#  14  Developer        2029 non-null   object
#  15  Rating           2006 non-null   object
# ...

# %%
test.describe(include='all')
# Out:
#                   id                       Name Platform  Year_of_Release  \
# count    3344.000000                       3344     3344      3300.000000
# unique           NaN                       3015       30              NaN
# top              NaN  Skylanders: SuperChargers       DS              NaN
# freq             NaN                          5      409              NaN
# mean     8299.097189                        NaN      NaN      2006.554848
# std      4789.893945                        NaN      NaN         6.022165
# min        11.000000                        NaN      NaN      1980.000000
# 25%      4120.500000                        NaN      NaN      2003.000000
# 50%      8381.000000                        NaN      NaN      2008.000000
# 75%     12341.750000                        NaN      NaN      2011.000000
# max     16697.000000                        NaN      NaN      2020.000000
#
#          Genre        Publisher     NA_Sales     EU_Sales     JP_Sales  \
# ...

# %%
test.isnull().sum()
# Out:
# id                    0
# Name                  0
# Platform              0
# Year_of_Release      44
# Genre                 0
# Publisher             7
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Critic_Score       1712
# Critic_Count       1712
# User_Score         1336
# User_Count         1793
# Developer          1315
# Rating             1338
# dtype: int64

# %%
del test['Rating']
del test['Developer']
del test['User_Count']
del test['User_Score']
del test['Critic_Score']
del test['Critic_Count']
del test['Publisher']
del test['Year_of_Release']
del test['Name']
del test['Platform']
del test['Genre']

# %%
test.head()
# Out:
#    id  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0  11      0.14      0.09      0.00         0.02
# 1  12      0.23      0.08      0.00         0.03
# 2  17      0.24      0.19      0.34         0.06
# 3  23      0.00      0.07      0.00         0.02
# 4  27      0.14      0.01      0.00         0.01

# %%
XX = test[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']]

# %%
X1 = train[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
y1 = train[['Global_Sales']]

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X1,y1)
pred = model.predict(XX)
pred = pd.DataFrame(pred,columns=['Global_Sales'])

# %%
pred.to_csv('J072_ML_Final_Prediction.csv')
